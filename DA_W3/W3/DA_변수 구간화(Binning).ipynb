# %%
# 필요한 패키지 설치
# !pip install xverse
from xverse.transformer import WOE
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.rcParams['figure.dpi'] = 150
# Out:
# Requirement already satisfied: xverse in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (1.0.5)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from xverse) (1.26.3)
# Requirement already satisfied: scikit-learn>=0.19.0 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from xverse) (1.4.0)
# Requirement already satisfied: scipy>=0.19.0 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from xverse) (1.12.0)
# Requirement already satisfied: statsmodels>=0.6.1 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from xverse) (0.14.1)
# Requirement already satisfied: pandas>=0.21.1 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from xverse) (2.2.0)
# Requirement already satisfied: matplotlib>=3.0.3 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from xverse) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from matplotlib>=3.0.3->xverse) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from matplotlib>=3.0.3->xverse) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from matplotlib>=3.0.3->xverse) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from matplotlib>=3.0.3->xverse) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from matplotlib>=3.0.3->xverse) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from matplotlib>=3.0.3->xverse) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from matplotlib>=3.0.3->xverse) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from matplotlib>=3.0.3->xverse) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from matplotlib>=3.0.3->xverse) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from pandas>=0.21.1->xverse) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from pandas>=0.21.1->xverse) (2023.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from scikit-learn>=0.19.0->xverse) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from scikit-learn>=0.19.0->xverse) (3.2.0)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from statsmodels>=0.6.1->xverse) (0.5.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.3->xverse) (3.17.0)
# Requirement already satisfied: six in c:\users\chaew\anaconda3\envs\bigdata\lib\site-packages (from patsy>=0.5.4->statsmodels>=0.6.1->xverse) (1.16.0)

# %%
# 데이터 불러오기
# https://www.kaggle.com/datasets/kamilpytlak/personal-key-indicators-of-heart-disease
df = pd.read_csv("../resource/W3/heart_2020_cleaned.csv")

# 데이터 샘플 확인
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
# BMI 컬럼의 분포 확인

df['BMI'].describe()
# Out:
# count    319795.000000
# mean         28.325399
# std           6.356100
# min          12.020000
# 25%          24.030000
# 50%          27.340000
# 75%          31.420000
# max          94.850000
# Name: BMI, dtype: float64

# %%
# BMI 컬럼 분포 시각화

# %matplotlib inline
sns.displot(df['BMI'],height = 5, aspect = 3)

# %%
# 임의로 단순 구간화

df1 = df.copy() # 데이터셋 복사

# 구간화용 빈 컬럼 생성 - 생략해도 되지만 바로 옆에 붙여 보기 위함
df1.insert(2, 'BMI_bin', 0) 

df1.loc[df1['BMI'] <= 20, 'BMI_bin'] = 'a'
df1.loc[(df1['BMI'] > 20) & (df1['BMI'] <= 30), 'BMI_bin'] = 'b'
df1.loc[(df1['BMI'] > 30) & (df1['BMI'] <= 40), 'BMI_bin'] = 'c'
df1.loc[(df1['BMI'] > 40) & (df1['BMI'] <= 50), 'BMI_bin'] = 'd'
df1.loc[(df1['BMI'] > 50) & (df1['BMI'] <= 60), 'BMI_bin'] = 'e'
df1.loc[(df1['BMI'] > 60) & (df1['BMI'] <= 70), 'BMI_bin'] = 'f'
df1.loc[df1['BMI'] > 70, 'BMI_bin'] = 'g'

df1.head()
# Out:
# C:\Users\chaew\AppData\Local\Temp\ipykernel_2456\3085778236.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'a' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.loc[df1['BMI'] <= 20, 'BMI_bin'] = 'a'
#   HeartDisease    BMI BMI_bin Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60       a     Yes              No     No             3.0
# 1           No  20.34       b      No              No    Yes             0.0
# 2           No  26.58       b     Yes              No     No            20.0
# 3           No  24.21       b      No              No     No             0.0
# 4           No  23.71       b      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
# 구간화 변수 분포 시각화

sns.displot(df1['BMI_bin'],height = 5, aspect = 3)

# %%
#  cut() 함수 사용하여 임의로 구간화
df1.insert(3, 'BMI_bin2', 0) # 구간화용 빈 컬럼 생성 

df1['BMI_bin2'] = pd.cut(df1.BMI, bins=[0, 20, 30, 40, 50, 60, 70, 95]
                         , labels=['a', 'b', 'c', 'd', 'e', 'f', 'g'])

df1.head()
# Out:
#   HeartDisease    BMI BMI_bin BMI_bin2 Smoking AlcoholDrinking Stroke  \
# 0           No  16.60       a        a     Yes              No     No
# 1           No  20.34       b        b      No              No    Yes
# 2           No  26.58       b        b     Yes              No     No
# 3           No  24.21       b        b      No              No     No
# 4           No  23.71       b        b      No              No     No
#
#    PhysicalHealth  MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0             3.0          30.0          No  Female        55-59  White
# 1             0.0           0.0          No  Female  80 or older  White
# 2            20.0          30.0          No    Male        65-69  White
# 3             0.0           0.0          No  Female        75-79  White
# 4            28.0           0.0         Yes  Female        40-44  White
#
#   Diabetic PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease  \
# 0      Yes              Yes  Very good        5.0    Yes            No
# 1       No              Yes  Very good        7.0     No            No
# 2      Yes              Yes       Fair        8.0    Yes            No
# 3       No               No       Good        6.0     No            No
# 4       No              Yes  Very good        8.0     No            No
#
#   SkinCancer
# 0        Yes
# 1         No
# 2         No
# 3        Yes
# 4         No

# %%
# BMI_bin2 구간 별 관측치 수 집계

df1.BMI_bin2.value_counts().to_frame().style.background_gradient(cmap='winter')
# Out:
# <style type="text/css">
# #T_b22ea_row0_col0 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_b22ea_row1_col0 {
#   background-color: #006cc9;
#   color: #f1f1f1;
# }
# #T_b22ea_row2_col0 {
#   background-color: #0012f6;
#   color: #f1f1f1;
# }
# #T_b22ea_row3_col0 {
#   background-color: #0011f6;
#   color: #f1f1f1;
# }
# #T_b22ea_row4_col0 {
#   background-color: #0002fe;
#   color: #f1f1f1;
# }
# #T_b22ea_row5_col0, #T_b22ea_row6_col0 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b22ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b22ea_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >BMI_bin2</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b22ea_level0_row0" class="row_heading level0 row0" >b</th>
#       <td id="T_b22ea_row0_col0" class="data row0 col0" >202548</td>
#     </tr>
#     <tr>
#       <th id="T_b22ea_level0_row1" class="row_heading level0 row1" >c</th>
#       <td id="T_b22ea_row1_col0" class="data row1 col0" >86198</td>
#     </tr>
#     <tr>
#       <th id="T_b22ea_level0_row2" class="row_heading level0 row2" >a</th>
#       <td id="T_b22ea_row2_col0" class="data row2 col0" >14699</td>
#     </tr>
#     <tr>
#       <th id="T_b22ea_level0_row3" class="row_heading level0 row3" >d</th>
#       <td id="T_b22ea_row3_col0" class="data row3 col0" >13839</td>
#     </tr>
#     <tr>
#       <th id="T_b22ea_level0_row4" class="row_heading level0 row4" >e</th>
#       <td id="T_b22ea_row4_col0" class="data row4 col0" >2019</td>
#     </tr>
#     <tr>
#       <th id="T_b22ea_level0_row5" class="row_heading level0 row5" >f</th>
#       <td id="T_b22ea_row5_col0" class="data row5 col0" >363</td>
#     </tr>
#     <tr>
#       <th id="T_b22ea_level0_row6" class="row_heading level0 row6" >g</th>
#       <td id="T_b22ea_row6_col0" class="data row6 col0" >129</td>
#     </tr>
#   </tbody>
# </table>

# %%
# qcut() 함수 사용하여 자동 구간화
df1.insert(4, 'BMI_bin3', 0) # 구간화용 빈 컬럼 생성 

df1['BMI_bin3'] = pd.qcut(df1.BMI, q=7, labels=['a', 'b', 'c', 'd', 'e', 'f', 'g'])

df1.head()
# Out:
#   HeartDisease    BMI BMI_bin BMI_bin2 BMI_bin3 Smoking AlcoholDrinking  \
# 0           No  16.60       a        a        a     Yes              No
# 1           No  20.34       b        b        a      No              No
# 2           No  26.58       b        b        d     Yes              No
# 3           No  24.21       b        b        b      No              No
# 4           No  23.71       b        b        b      No              No
#
#   Stroke  PhysicalHealth  MentalHealth  ...     Sex  AgeCategory   Race  \
# 0     No             3.0          30.0  ...  Female        55-59  White
# 1    Yes             0.0           0.0  ...  Female  80 or older  White
# 2     No            20.0          30.0  ...    Male        65-69  White
# 3     No             0.0           0.0  ...  Female        75-79  White
# 4     No            28.0           0.0  ...  Female        40-44  White
#
#   Diabetic PhysicalActivity  GenHealth SleepTime  Asthma KidneyDisease  \
# 0      Yes              Yes  Very good       5.0     Yes            No
# 1       No              Yes  Very good       7.0      No            No
# 2      Yes              Yes       Fair       8.0     Yes            No
# 3       No               No       Good       6.0      No            No
# 4       No              Yes  Very good       8.0      No            No
#
#   SkinCancer
# 0        Yes
# 1         No
# 2         No
# 3        Yes
# 4         No
#
# [5 rows x 21 columns]

# %%
# BMI_bin3 구간 별 관측치 수 집계

df1.BMI_bin3.value_counts().to_frame().style.background_gradient(cmap='winter')
# Out:
# <style type="text/css">
# #T_fbc90_row0_col0 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_fbc90_row1_col0 {
#   background-color: #0085bc;
#   color: #f1f1f1;
# }
# #T_fbc90_row2_col0 {
#   background-color: #0082be;
#   color: #f1f1f1;
# }
# #T_fbc90_row3_col0 {
#   background-color: #0075c4;
#   color: #f1f1f1;
# }
# #T_fbc90_row4_col0 {
#   background-color: #0043de;
#   color: #f1f1f1;
# }
# #T_fbc90_row5_col0 {
#   background-color: #0029eb;
#   color: #f1f1f1;
# }
# #T_fbc90_row6_col0 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fbc90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbc90_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >BMI_bin3</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbc90_level0_row0" class="row_heading level0 row0" >b</th>
#       <td id="T_fbc90_row0_col0" class="data row0 col0" >47309</td>
#     </tr>
#     <tr>
#       <th id="T_fbc90_level0_row1" class="row_heading level0 row1" >a</th>
#       <td id="T_fbc90_row1_col0" class="data row1 col0" >45980</td>
#     </tr>
#     <tr>
#       <th id="T_fbc90_level0_row2" class="row_heading level0 row2" >d</th>
#       <td id="T_fbc90_row2_col0" class="data row2 col0" >45944</td>
#     </tr>
#     <tr>
#       <th id="T_fbc90_level0_row3" class="row_heading level0 row3" >f</th>
#       <td id="T_fbc90_row3_col0" class="data row3 col0" >45805</td>
#     </tr>
#     <tr>
#       <th id="T_fbc90_level0_row4" class="row_heading level0 row4" >g</th>
#       <td id="T_fbc90_row4_col0" class="data row4 col0" >45255</td>
#     </tr>
#     <tr>
#       <th id="T_fbc90_level0_row5" class="row_heading level0 row5" >e</th>
#       <td id="T_fbc90_row5_col0" class="data row5 col0" >44977</td>
#     </tr>
#     <tr>
#       <th id="T_fbc90_level0_row6" class="row_heading level0 row6" >c</th>
#       <td id="T_fbc90_row6_col0" class="data row6 col0" >44525</td>
#     </tr>
#   </tbody>
# </table>

# %%
# BMI_bin3 분포 시각화

sns.displot(df1['BMI_bin3'],height = 5, aspect = 3)

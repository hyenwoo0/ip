# %% [markdown]
# # 1. Naver Open API 접속해서 검색 하기
#
# ## (1) Naver developers 사이트 접속 (검색 API 사용 등록)
#
# - client_id 생성
# - client_secret 생성
#
# ## (2) request로 호출하기
#
# - request = urllib.request.Request(url)
# - request.add_header("X-Naver-Client-Id",client_id)
# - request.add_header("X-Naver-Client-Secret",client_secret)
# - response = urllib.request.urlopen(request)

# %%
import os
import sys
import urllib.request

client_id = "YOUR_CLIENT_ID" # Naver에서 등록하여 받은 ID
client_secret = "YOUR_CLIENT_SECRET" # Naver에서 등록하여 받은 ID

# encText = urllib.parse.quote("검색할 단어")
encText = urllib.parse.quote("축구 아시안컵")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 13 Mar 2024 09:36:37 +0900",
# 	"total":117281,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"골장면 재방송 다시보기 한국 <b>축구 아시안컵<\/b> 8강전 호주전",
# 			"link":"https:\/\/blog.naver.com\/lune_etoile\/223340977073",
# 			"description":"2024년 02월 03일 호주 대한민국 하이라이트 골장면 재방송 다시보기 한국 <b>축구 아시안컵<\/b> 8강전 호주전... 한국 호주 축구 대한민국 호주 전적은 28전 8승 11무 9패로 그 동안 아시안컵에서 만났던 대결 상대 중... ",
# 			"bloggername":"일상",
# 			"bloggerlink":"blog.naver.com\/lune_etoile",
# 			"postdate":"20240201"
# 		},
# 		{
# 			"title":"<b>아시안컵<\/b> 한국 호주 8강 경기 한국<b>축구<\/b> 4강 진출 중국 일본... ",
# 			"link":"https:\/\/blog.naver.com\/jamjma98\/223342620090",
# 			"description":"&quot;역시 우리 캡틴 멋져&quot;라는 토트넘 팬들의 웅원 댓글이 많이 보였습니다. 한국<b>축구<\/b>의 <b>아시안컵<\/b> 4강 진출을 축하하며, 다음 4강 요르단과의 경기에서도 좋은 결과 있기를 바랍니다^^",
# 			"bloggername":"너구리 가족의 땅굴 밖 여행",
# 			"bloggerlink":"blog.naver.com\/jamjma98",
# 			"postdate":"20240203"
# 		},
# 		{
# 			"title":"한국 사우디아라비아 <b>축구 아시안컵<\/b> 중계 보러가기",
# 			"link":"https:\/\/blog.naver.com\/dydxodi333\/223338785754",
# 			"description":"https:\/\/naver.me\/5R8XYwSu 한국 사우디아라비아 <b>축구<\/b> 중계는 위에서 보시면 되겠습니다. <b>아시안컵<\/b> 중계가 새벽에 하는 것은 거의 보지 못한 것 같은데 이번 경기는 새벽 1시에 열려서 시청하기에 부담이 되시는... ",
# 			"bloggername":"당신의 리즈시절은",
# 			"bloggerlink":"blog.naver.com\/dydxodi333",
# 			"postdate":"20240130"
# 		},
# 		{
# 			"title":"대한민국 호주 8강 <b>축구<\/b> 중계 전적 심판 <b>아시안컵<\/b> 무료... ",
# 			"link":"https:\/\/blog.naver.com\/shieldmaster\/223341014539",
# 			"description":"대한민국 호주 8강 <b>축구<\/b> 중계 전적 심판 <b>아시안컵<\/b> 무료 실시간tv 하이라이트 영상 승부차기 대한민국 호주 8강 <b>축구<\/b> 중계 전적 심판 <b>아시안컵<\/b> 무료 실시간tv 하이라이트 영상 승부차기 64년만에 우승을 노리는... ",
# 			"bloggername":"엑스펠",
# 			"bloggerlink":"blog.naver.com\/shieldmaster",
# 			"postdate":"20240202"
# 		},
# 		{
# 			"title":"2024년_이가네 양꼬치, <b>축구 아시안컵<\/b>, 발렌타인 데이, 스키장",
# 			"link":"https:\/\/blog.naver.com\/ginaaac\/223373875527",
# 			"description":"야경✨ <b>아시안컵<\/b> 경기가 있던 날 어디랑 했더라 결론은 이겼음! 승리가 중요한 것! 훗날 <b>아시안컵<\/b>은 국대팀 내 잡음으로 지저분해지긴 했지만.. 얼마만에 찾는 경복궁인가요 “저는 초등학생 때? 와보고 처음인... ",
# 			"bloggername":"GinaC",
# 			"bloggerlink":"blog.naver.com\/ginaaac",
# 			"postdate":"20240305"
# 		},
# 		{
# 			"title":"<b>아시안컵<\/b> 4강 결과 한국 요르단 하이라이트 한국 <b>축구<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/qhadldhaus98\/223346781334",
# 			"description":"이번 <b>아시안컵<\/b> 한국 <b>축구<\/b> 색깔이 뭔가요????????? 지금까지의 경기를 쭈욱 지켜본 우리는 전술적으로 뭘 하고 싶은지 도통 알수가 없습니다. 선수들의 능력과 정신력과 투지만으로는 4강 문턱을 넘을 수... ",
# 			"bloggername":"♬ 보미의 골프 라이프",
# 			"bloggerlink":"blog.naver.com\/qhadldhaus98",
# 			"postdate":"20240207"
# 		},
# 		{
# 			"title":"한국 바레인 <b>축구<\/b> 중계, <b>아시안컵<\/b> E조 쏠리는 시선",
# 			"link":"https:\/\/bluesoccer.net\/m\/8776",
# 			"description":"축구 한국 바레인 축구 중계, 아시안컵 E조 쏠리는 시선 나이스블루 2024. 1. 13. 14:35 한국 바레인 축구... 2019 아시안컵 16강에서도 연장전 끝에 2-1로 이겼다. 이러한 흐름이라면 한국 바레인 <b>축구 아시안컵<\/b> E조... ",
# 			"bloggername":"나이스블루",
# 			"bloggerlink":"https:\/\/bluesoccer.net\/",
# 			"postdate":"20240113"
# 		},
# 		{
# 			"title":"일본 북한 여자<b>축구<\/b> 중계 AFC U20 여자 <b>아시안컵<\/b> 조별리그... ",
# 			"link":"https:\/\/blog.naver.com\/olengelight\/223378817748",
# 			"description":"일본 북한 여자<b>축구<\/b> 중계 AFC U20 여자 <b>아시안컵<\/b> 조별리그 3차전 2024년 3월 10일 경기일정 시간 채널 U20 순위 전력분석 실시간 라이브 온라인 시청 방송 tv 채널 #일본북한여자<b>축구<\/b> #U20여자<b>아시안컵<\/b>... ",
# 			"bloggername":":: 밀감색 조명 ♥ 희나 ::",
# 			"bloggerlink":"blog.naver.com\/olengelight",
# 			"postdate":"20240310"
# 		},
# 		{
# 			"title":"2024 AFC U-20 여자<b>축구 아시안컵<\/b> A조 3월3일 호주전 결과리뷰... ",
# 			"link":"https:\/\/blog.naver.com\/gwf21\/223372090039",
# 			"description":"금일은 2024 AFC U-20 여자<b>축구 아시안컵<\/b> A조에서 3월3일 오후 17시에 있었던 호주전에 대해서 나름... 아시아축구연맹(AFC) U-20 여자 아시안컵 조별리그 A조 1차전에서 호주에 1대2로 졌습니다. 대한민국은... ",
# 			"bloggername":"❤️MIN’s 의 다락방❤️",
# 			"bloggerlink":"blog.naver.com\/gwf21",
# 			"postdate":"20240304"
# 		},
# 		{
# 			"title":"2024년 02월 07일 요르단 대한민국 중계 <b>축구<\/b> 한국 <b>아시안컵<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/dbswoqja119\/223345699761",
# 			"description":"2023 카타르 <b>아시안컵<\/b> <b>축구<\/b> 대표팀 감독은 클리스만이며 총 26명의 선수들로 구성되었습니다. 골키퍼 (3명) 조현우(울산현대) 송범근(쇼난벨마레) 김승규(알 샤밥) 수비수 (9명) 김민재(바이에른 뮌헨) 김진수... ",
# 			"bloggername":"오늘내일",
# 			"bloggerlink":"blog.naver.com\/dbswoqja119",
# 			"postdate":"20240206"
# 		}
# 	]
# }

# %% [markdown]
# # 2. Naver news 크롤링 하기
#
# - 네이버 뉴스에서 월드컵 관련 기사 크롤링 해서 파일로 저장하기

# %% [markdown]
# ## (1) 전체 작업 설계하기
#
# 1. 검색어 지정하기
#
#         srcText = '월드컵'
#
# 2. 네이버 뉴스 검색하기
#
#         getNaverSearch()
#
#         (1) url 구성하기
#
#             - url = base + node + srcText
#
#         (2) url 접속과 검색 요청하기
#
#             - urllib.request.urlopen()
#
#         (3) 요청 결과를 응답 json으로 받기
#
#             - json.load()
#
# 3. 응답 데이터를 정리하여 리스트에 저장하기
#
#         getPostData()
#
# 4. 리스트를 JSON 파일로 저장하기
#
#         json.dumps()

# %%
import os
import sys
import urllib.request
import datetime
import time
import json

def getRequestUrl(url):
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)

    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())            
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" %(datetime.datetime.now(), url))
        return None


def getNaverSearch(node, srcText, page_start, display):
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % node
    parameters = "?query=%s&start=%s&display=%s" %(urllib.parse.quote(srcText), page_start, display)

    url = base + node + parameters
    responseDecode = getRequestUrl(url)

    if (responseDecode == None):
        return None
    else:
        return json.loads(responseDecode)
    
def getPostData(post, jsonResult, cnt):
    title = post['title']
    description = post['description']
    org_link = post['originallink']
    link = post['link']

    pDate = datetime.datetime.strptime(post['pubDate'], '%a, %d %b %Y %H:%M:%S +0900')
    pDate = pDate.strftime('%Y-%m-%d %H:%M:%S')

    jsonResult.append({'cnt':cnt, 'title':title, 'description':description, 'org_link': org_link, 'link': org_link, 'pDate':pDate})
    return

def main():
    node = 'news' # 크롤링 대상
    srcText = input('검색어를 입력하세요: ')
    cnt = 0
    jsonResult = []

    jsonResponse = getNaverSearch(node, srcText, 1, 100)
    total = jsonResponse['total']

    while ((jsonResponse != None) and (jsonResponse['display'] != 0)):
        for post in jsonResponse['items']:
            cnt += 1
            getPostData(post, jsonResult, cnt)

        start = jsonResponse['start'] + jsonResponse['display']
        jsonResponse = getNaverSearch(node, srcText, start, 100)
    
    print('전체 검색 : %d 건' %total)

    with open('%s_naver_%s.json' % (srcText, node), 'w', encoding='utf8') as outfile:
        jsonFile = json.dumps(jsonResult, indent = 4, sort_keys = True, ensure_ascii = False)
        outfile.write(jsonFile)

    print('가져온 데이터 : %d 건' %(cnt))
    print('%s_naver_%s.json SAVED' %(srcText, node))

if __name__ == '__main__':
    main()
# Out:
# [2024-03-13 09:36:47.737917] Url Request Success
# [2024-03-13 09:36:48.177267] Url Request Success
# [2024-03-13 09:36:48.577647] Url Request Success
# [2024-03-13 09:36:48.963468] Url Request Success
# [2024-03-13 09:36:49.354346] Url Request Success
# [2024-03-13 09:36:49.738675] Url Request Success
# [2024-03-13 09:36:50.141246] Url Request Success
# [2024-03-13 09:36:50.537306] Url Request Success
# [2024-03-13 09:36:50.959019] Url Request Success
# [2024-03-13 09:36:51.396382] Url Request Success
# HTTP Error 400: Bad Request
# [2024-03-13 09:36:51.711926] Error for URL : https://openapi.naver.com/v1/search/news.json?query=%EC%9D%B4%EA%B0%95%EC%9D%B8&start=1001&display=100
# 전체 검색 : 128421 건
# 가져온 데이터 : 1000 건
# 이강인_naver_news.json SAVED

# %% [markdown]
# ### Naver 검색 url
#
# - 뉴스 : https://openapi.naver.com/v1/search/news.json
# - 블로그 : https://openapi.naver.com/v1/search/blog.json
# - 카페 : https://openapi.naver.com/v1/search/cafearticle.json
# - 영화 : https://openapi.naver.com/v1/search/movie.json
# - 쇼핑 : https://openapi.naver.com/v1/search/shop.json

# %% [markdown]
# ### 요청 변수
#
# - query : 검색을 원하는 문자열이며 UTF-8로 인코딩한다
# - start : 검색 시작 위치로 최대 1000까지 가능 (기본값 1)
# - display : 검색 결과 출력 건수를 지정 10(기본값) ~ 100(최대값)
#
# ### 응답 변수
# - items : 검색 결과로 title, originallink, link, description, pubData를 포함
# - title : 검색 결과 문서의 제목
# - link : 검색 결과 문서를 제공하는 네이버의 하이퍼텍스트 link
# - originallink : 검색 결과 문서를 제공하는 언론사의 하이퍼텍스트 link
# - description : 검색 결과 문서의 내용을 요약한 정보
# - pubDate : 검색 결과 문서가 네이버에 제공된 시간

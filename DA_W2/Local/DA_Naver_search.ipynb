# %% [markdown]
# # 1. Naver Open API 접속해서 검색 하기
#
# ## (1) Naver developers 사이트 접속 (검색 API 사용 등록)
#
# - client_id 생성
# - client_secret 생성
#
# ## (2) request로 호출하기
#
# - request = urllib.request.Request(url)
# - request.add_header("X-Naver-Client-Id",client_id)
# - request.add_header("X-Naver-Client-Secret",client_secret)
# - response = urllib.request.urlopen(request)

# %%
import os
import sys
import urllib.request

client_id = "a6lDe6AQ3XzpNsDWNABn" # Naver에서 등록하여 받은 ID
client_secret = "NDiFcoRM8x" # Naver에서 등록하여 받은 ID

# encText = urllib.parse.quote("검색할 단어")
encText = urllib.parse.quote("축구 아시안컵")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 13 Mar 2025 10:28:46 +0900",
# 	"total":127879,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"u20 <b>아시안컵<\/b> 중계 4강 <b>축구<\/b> 한국 사우디 대한민국... ",
# 			"link":"https:\/\/blog.naver.com\/agla1\/223774522790",
# 			"description":"✅ afc u20 <b>아시안컵<\/b> <b>축구<\/b> 중계 보러가기 mbc sports + 채널 번호를 보았을 때 KT 올레 TV에서는 60번, SK브로드밴드의 Btv에서는 983번, LG U+TV에서는 106번으로 설정되어 있어요. 스카이라이프 사용자는 205번에서... ",
# 			"bloggername":"소소한 매일",
# 			"bloggerlink":"blog.naver.com\/agla1",
# 			"postdate":"20250226"
# 		},
# 		{
# 			"title":"한국 사우디아라비아 <b>축구 아시안컵<\/b> 중계 보러가기",
# 			"link":"https:\/\/blog.naver.com\/dydxodi333\/223338785754",
# 			"description":"https:\/\/naver.me\/5R8XYwSu 한국 사우디아라비아 <b>축구<\/b> 중계는 위에서 보시면 되겠습니다. <b>아시안컵<\/b> 중계가 새벽에 하는 것은 거의 보지 못한 것 같은데 이번 경기는 새벽 1시에 열려서 시청하기에 부담이 되시는... ",
# 			"bloggername":"당신의 리즈시절은",
# 			"bloggerlink":"blog.naver.com\/dydxodi333",
# 			"postdate":"20240130"
# 		},
# 		{
# 			"title":"u20 <b>아시안컵<\/b> 4강 한국 사우디... 사우디아라비아 <b>축구<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/dydghks3250\/223773758304",
# 			"description":"아시아<b>축구<\/b>연맹(AFC) U-20 <b>아시안컵<\/b>에 출전한 한국이 조별 예선을 1위로 통과한 데 이어, 8강전에서 디펜딩 챔피언 우즈베키스탄과 연장전, 승부차기까지 가는 혈투 끝에 승리를 거두고 준결승에 올랐습니다.... ",
# 			"bloggername":"❤️ ✅kGn뉴스 ✅❤️",
# 			"bloggerlink":"blog.naver.com\/dydghks3250",
# 			"postdate":"20250226"
# 		},
# 		{
# 			"title":"u20 <b>아시안컵<\/b> 4강 한국 사우디 <b>축구<\/b> 중계 tv 채널 준결승",
# 			"link":"https:\/\/blog.naver.com\/kki1129\/223774696788",
# 			"description":"사우디 <b>아시안컵<\/b>4강▼ 실시간 중계 보는 곳 kbs,sbs,mbc 틀어도 <b>축구<\/b>안해서 황당했다면? 아래에서 빠르게 보세요. 이 경기에서 승리하면 결승전에서 일본 또는 호주와 맞붙게 돼요. 아래보면 동일시간대에 AFC... ",
# 			"bloggername":"여유롭고 가치있는 삶을 위해",
# 			"bloggerlink":"blog.naver.com\/kki1129",
# 			"postdate":"20250226"
# 		},
# 		{
# 			"title":"응원 준비 완료! 카타르 <b>아시안컵<\/b> <b>축구<\/b> 국대 일정 알아보기",
# 			"link":"https:\/\/kyobolifeblog.co.kr\/4856",
# 			"description":"카타르 <b>아시안컵<\/b> <b>축구<\/b> 국대 일정 알아보기 2024. 1. 15. 15:10 ✅ 2023 카타르 <b>아시안컵<\/b> 3줄 요약 ✅ 64년 만에 우승 도전! 이번엔 가능할까? ✅ E조 편성! 손흥민, 김민재, 황희찬, 이강인 등 해외파 총출동 ✅ 경기... ",
# 			"bloggername":"교봉이",
# 			"bloggerlink":"https:\/\/kyobolifeblog.co.kr\/",
# 			"postdate":"20240115"
# 		},
# 		{
# 			"title":"u20 <b>아시안컵<\/b> 명단 일정 중계 <b>축구<\/b> 방송",
# 			"link":"https:\/\/blog.naver.com\/combine8589\/223761911202",
# 			"description":"u20 <b>아시안컵<\/b> 명단 일정 중계 <b>축구<\/b> 방송에 대해 알려드리겠습니다. 중국 선전 스타디움에서 진행되며 지난 2월 14일 시리아와 대결을 하였습니다. 2대1로 승리하였는데요. 이번 글에서 분석까지... ",
# 			"bloggername":"유리의 하루",
# 			"bloggerlink":"blog.naver.com\/combine8589",
# 			"postdate":"20250215"
# 		},
# 		{
# 			"title":"한국 사우디 <b>축구<\/b> 중계 U20 <b>아시안컵<\/b> 경기시간 대한민국... ",
# 			"link":"https:\/\/blog.naver.com\/ody301\/223774601696",
# 			"description":"한국 사우디 <b>축구<\/b> 중계 U20 <b>아시안컵<\/b> 경기시간 대한민국 사우디아라비아 실시간 TV 채널 하이라이트 영상 골모음 결승전 일정 아시아<b>축구<\/b>연맹(AFC)에서 주관하는 2025 U20 <b>아시안컵<\/b> 대회가 이제 단 두경기만을... ",
# 			"bloggername":"아르의 알콩달콩",
# 			"bloggerlink":"blog.naver.com\/ody301",
# 			"postdate":"20250226"
# 		},
# 		{
# 			"title":"afc u20 <b>아시안컵<\/b> 한국 사우디 4강 <b>축구<\/b> 중계 대한민국... ",
# 			"link":"https:\/\/blog.naver.com\/loveisimpress\/223774908236",
# 			"description":"afc u20 <b>아시안<\/b>컴 한국 사우디 <b>축구<\/b> 중계는 아래에서 바로 보실 수 있어요! ▼<b>축구<\/b> 중계 바로보기▼ 1. AFC U20 <b>아시안컵<\/b> 이 경기는 아시아<b>축구<\/b>연맹이 주관하는 20세 이하의 <b>축구<\/b> 대표팀들의 대회랍니다.... ",
# 			"bloggername":"경제 IT로거",
# 			"bloggerlink":"blog.naver.com\/loveisimpress",
# 			"postdate":"20250226"
# 		},
# 		{
# 			"title":"2024년 01월 15일 대한민국 바레인 한국 <b>축구 아시안컵<\/b> 경기... ",
# 			"link":"https:\/\/blog.naver.com\/travelhyuk\/223322909104",
# 			"description":"2024년 01월 15일 대한민국 바레인 한국 <b>축구 아시안컵<\/b> 일정 명단 중계 사실 위상만 따져보자면 23세... 이상으로 아시안컵 E조 조별리그 첫경기로 치러질 2024년 01월 15일 대한민국 바레인 축구 경기 일정 및... ",
# 			"bloggername":"임씨의 지구를 지켜라!!",
# 			"bloggerlink":"blog.naver.com\/travelhyuk",
# 			"postdate":"20240115"
# 		},
# 		{
# 			"title":"한국 일본 <b>축구<\/b> U20 <b>아시안컵<\/b> 중계 조별리그 D조 3차전 2025년... ",
# 			"link":"https:\/\/blog.naver.com\/olengelight\/223765064646",
# 			"description":"한국 일본 <b>축구<\/b> U20 <b>아시안컵<\/b> 중계 조별리그 D조 3차전 2025년 2월 19일 대한민국 일본 U-20 <b>아시안컵<\/b> 한일전 실시간 생중계 티비 국가대표팀 명단 모바일 무료 쿠팡플레이 대한민국 20세 이하 대표팀이... ",
# 			"bloggername":":: 밀감색 조명 ♥ 희나 ::",
# 			"bloggerlink":"blog.naver.com\/olengelight",
# 			"postdate":"20250220"
# 		}
# 	]
# }

# %% [markdown]
# # 2. Naver news 크롤링 하기
#
# - 네이버 뉴스에서 월드컵 관련 기사 크롤링 해서 파일로 저장하기

# %% [markdown]
# ## (1) 전체 작업 설계하기
#
# 1. 검색어 지정하기
#
#         srcText = '월드컵'
#
# 2. 네이버 뉴스 검색하기
#
#         getNaverSearch()
#
#         (1) url 구성하기
#
#             - url = base + node + srcText
#
#         (2) url 접속과 검색 요청하기
#
#             - urllib.request.urlopen()
#
#         (3) 요청 결과를 응답 json으로 받기
#
#             - json.load()
#
# 3. 응답 데이터를 정리하여 리스트에 저장하기
#
#         getPostData()
#
# 4. 리스트를 JSON 파일로 저장하기
#
#         json.dumps()

# %%
import os
import sys
import urllib.request
import datetime
import time
import json

def getRequestUrl(url):
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)

    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())            
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" %(datetime.datetime.now(), url))
        return None


def getNaverSearch(node, srcText, page_start, display):
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % node
    parameters = "?query=%s&start=%s&display=%s" %(urllib.parse.quote(srcText), page_start, display)

    url = base + node + parameters
    responseDecode = getRequestUrl(url)

    if (responseDecode == None):
        return None
    else:
        return json.loads(responseDecode)
    
def getPostData(post, jsonResult, cnt):
    title = post['title']
    description = post['description']
    org_link = post['originallink']
    link = post['link']

    pDate = datetime.datetime.strptime(post['pubDate'], '%a, %d %b %Y %H:%M:%S +0900')
    pDate = pDate.strftime('%Y-%m-%d %H:%M:%S')

    jsonResult.append({'cnt':cnt, 'title':title, 'description':description, 'org_link': org_link, 'link': org_link, 'pDate':pDate})
    return

def main():
    node = 'news' # 크롤링 대상
    srcText = input('검색어를 입력하세요: ')
    cnt = 0
    jsonResult = []

    jsonResponse = getNaverSearch(node, srcText, 1, 100)
    total = jsonResponse['total']

    while ((jsonResponse != None) and (jsonResponse['display'] != 0)):
        for post in jsonResponse['items']:
            cnt += 1
            getPostData(post, jsonResult, cnt)

        start = jsonResponse['start'] + jsonResponse['display']
        jsonResponse = getNaverSearch(node, srcText, start, 100)
    
    print('전체 검색 : %d 건' %total)

    with open('%s_naver_%s.json' % (srcText, node), 'w', encoding='utf8') as outfile:
        jsonFile = json.dumps(jsonResult, indent = 4, sort_keys = True, ensure_ascii = False)
        outfile.write(jsonFile)

    print('가져온 데이터 : %d 건' %(cnt))
    print('%s_naver_%s.json SAVED' %(srcText, node))

if __name__ == '__main__':
    main()
# Out:
# [2025-03-13 10:55:53.095478] Url Request Success
# [2025-03-13 10:55:53.350790] Url Request Success
# [2025-03-13 10:55:53.824025] Url Request Success
# [2025-03-13 10:55:54.573882] Url Request Success
# [2025-03-13 10:55:55.153614] Url Request Success
# [2025-03-13 10:55:55.473457] Url Request Success
# [2025-03-13 10:55:56.176042] Url Request Success
# [2025-03-13 10:55:56.649064] Url Request Success
# [2025-03-13 10:55:57.503912] Url Request Success
# [2025-03-13 10:55:57.915923] Url Request Success
# [2025-03-13 10:55:58.350856] Url Request Success
# HTTP Error 400: Bad Request
# [2025-03-13 10:55:58.492351] Error for URL : https://openapi.naver.com/v1/search/news.json?query=%EC%B5%9C%EC%9E%AC%ED%95%B4&start=1099&display=100
# 전체 검색 : 16133 건
# 가져온 데이터 : 1098 건
# 최재해_naver_news.json SAVED

# %% [markdown]
# ### Naver 검색 url
#
# - 뉴스 : https://openapi.naver.com/v1/search/news.json
# - 블로그 : https://openapi.naver.com/v1/search/blog.json
# - 카페 : https://openapi.naver.com/v1/search/cafearticle.json
# - 영화 : https://openapi.naver.com/v1/search/movie.json
# - 쇼핑 : https://openapi.naver.com/v1/search/shop.json

# %% [markdown]
# ### 요청 변수
#
# - query : 검색을 원하는 문자열이며 UTF-8로 인코딩한다
# - start : 검색 시작 위치로 최대 1000까지 가능 (기본값 1)
# - display : 검색 결과 출력 건수를 지정 10(기본값) ~ 100(최대값)
#
# ### 응답 변수
# - items : 검색 결과로 title, originallink, link, description, pubData를 포함
# - title : 검색 결과 문서의 제목
# - link : 검색 결과 문서를 제공하는 네이버의 하이퍼텍스트 link
# - originallink : 검색 결과 문서를 제공하는 언론사의 하이퍼텍스트 link
# - description : 검색 결과 문서의 내용을 요약한 정보
# - pubDate : 검색 결과 문서가 네이버에 제공된 시간

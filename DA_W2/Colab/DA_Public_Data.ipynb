# %% [markdown]
# # 공공 데이터 API 기반 크롤링
#
# ## 1. 출입국관광통계서비스 - 개발 계정 받기

# %%
# Service_Enc_Key = "QYiQcd%2Biv7G6qpmPO2WR1Qo%2FrSghkwXi9Di3hA3nZTOH4d5RXgTRGLsHJ5aLg%2BVS0nDMAwotJ8SLFuBjWh8Mag%3D%3D"
Service_Enc_Key = "QYiQcd%2Biv7G6qpmPO2WR1Qo%2FrSghkwXi9Di3hA3nZTOH4d5RXgTRGLsHJ5aLg%2BVS0nDMAwotJ8SLFuBjWh8Mag%3D%3D"
# Service_Dec_Key = "QYiQcd+iv7G6qpmPO2WR1Qo/rSghkwXi9Di3hA3nZTOH4d5RXgTRGLsHJ5aLg+VS0nDMAwotJ8SLFuBjWh8Mag=="
Service_Dec_Key = "QYiQcd+iv7G6qpmPO2WR1Qo/rSghkwXi9Di3hA3nZTOH4d5RXgTRGLsHJ5aLg+VS0nDMAwotJ8SLFuBjWh8Mag=="

# %%
# ServiceKey="Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D"
ServiceKey="Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D"

# %%
# import requests

# url = 'http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList'
# # params ={'serviceKey' : ServiceKey, 'YM' : '201201', 'NAT_CD' : '112', 'ED_CD' : 'E' }
# # params ={'serviceKey' : Service_Enc_Key, 'YM' : '201201', 'NAT_CD' : '112', 'ED_CD' : 'E' }
# params = {
#     # 'serviceKey': urllib.parse.quote(ServiceKey),  # URL 인코딩
#     'serviceKey': ServiceKey,  # URL 인코딩
#     'YM': '201201',
#     'NAT_CD': '112',
#     'ED_CD': 'E'
# }

# response = requests.get(url, params=params)
# print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><responseTime>2025-03-06T16:33:21.283+09:00</responseTime><resultCode>30</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>'

# %%
import requests
import urllib.parse

url = (
    "http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList"
    + "?serviceKey=" + ServiceKey  # URL 인코딩 없이 테스트
    + "&YM=201201"
    + "&NAT_CD=112"
    + "&ED_CD=E"
)

response = requests.get(url)
print(response.url)
print(response.content)
# Out:
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201201&NAT_CD=112&ED_CD=E
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>0000</resultCode><resultMsg>OK</resultMsg></header><body><items><item><ed>\xeb\xb0\xa9\xed\x95\x9c\xec\x99\xb8\xeb\x9e\x98\xea\xb4\x80\xea\xb4\x91\xea\xb0\x9d</ed><edCd>E</edCd><natCd>112</natCd><natKorNm>\xec\xa4\x91  \xea\xb5\xad</natKorNm><num>167022</num><rnum>1</rnum><ym>201201</ym></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>1</totalCount></body></response>'

# %% [markdown]
# ## 2. 공공데이터 크롤링하기
#
# - Open API를 이용하여 출입국관광통계서비스 데이터 중에서 2017년부터 현재까지 입국한 중국인의 수를 크롤링해 보자
#
# ### (1) 전체 작업 설계하기
#
# #### 1. 데이터를 수집할 국가코드와 연도 입력하기
#
#         - national_code, nStartYear, nEndYear
#
# #### 2. 데이터 수집 요청하기: getTourismStatsService()
#
#         - url 구성하여 데이터 요청하기: getTourismStatsItem()
#         - url 접속하고 요청하기: getRequestUrl()
#         - 응답 데이터를 리스트로 구성하기: jsonResult.result
#
# #### 3. 데이터를 JSON 파일과 CSV 파일로 저장하기: json.dumps().to_csv()

# %%
# !pip install timer
# Out:
# Collecting timer
#   Downloading timer-0.3.0-py3-none-any.whl.metadata (2.5 kB)
# Downloading timer-0.3.0-py3-none-any.whl (8.0 kB)
# Installing collected packages: timer
# Successfully installed timer-0.3.0

# %%
import os
import sys
import urllib.request
import datetime
import timer
import json
import pandas as pd

# ServiceKey = Service_Dec_Key
ServiceKey="Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D"


def getRequestUrl(url):
    req = urllib.request.Request(url)
    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')

    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None

def getTourismStatsItem(yyyymm, nat_cd, ed_cd):
    service_url = "http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList"
    parameters = "?_type=json&serviceKey=" + ServiceKey # 인증키
    parameters += "&YM=" + yyyymm
    parameters += "&NAT_CD=" + nat_cd
    parameters += "&ED_CD=" + ed_cd

    url = service_url + parameters
    print(url)
    responseDecode = getRequestUrl(url)

    if(responseDecode == None):
        return None
    else:
        return json.loads(responseDecode)

def getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear):
    jsonResult = []
    result = []
    natName = ''
    dataEND = "{0}{1:0>2}".format(str(nEndYear), str(12))  # 데이터 끝 초기화
    isDataEnd = 0  # 데이터 끝 확인용 flag 초기화
    ed = '' # 오류 발생에 따른 수정 : local variable 'ed' referenced before assignment

    for year in range(nStartYear, nEndYear):
        for month in range(1, 13):
            if(isDataEnd == 1): break   # 데이터 끝 flag 설정되어 있으면 작업 중지
            yyyymm = "{0}{1:0>2}".format(str(year), str(month))
            jsonData = getTourismStatsItem(yyyymm, nat_cd, ed_cd)
            if (jsonData['response']['header']['resultMsg'] == 'OK'):
                # 입력된 범위까지 수집하지 않았지만, 더이상 제공되는 데이터가 없는 마지막 항목인 경우
                if jsonData['response']['body']['items'] == '':
                    isDataEnd = 1  # 데이터 끝 flag 설정
                    dataEND = '{0}{1:0>2}'.format(str(year), str(month-1))
                    print("데이터 없음.... \n 제공되는 통계 데이터는 %s년 %s월까지입니다." %(str(year), str(month-1)))
                    break
                # jsonData를 출력하여 확인
                print(json.dumps(jsonData, indent = 4, sort_keys = True, ensure_ascii = False))
                natName = jsonData['response']['body']['items']['item']['natKorNm']
                natName = natName.replace(' ', '')
                num = jsonData['response']['body']['items']['item']['num']
                ed = jsonData['response']['body']['items']['item']['ed']
                print('[ %s_%s : %s]' %(natName, yyyymm, num))
                print('---------------------------------------------------')
                jsonResult.append({'nat_name' : natName, 'nat_cd': nat_cd, 'yyyymm': yyyymm, 'visit_cnt': num})
                result.append([natName, nat_cd, yyyymm, num])

    return (jsonResult, result, natName, ed, dataEND)


def main():
    jsonResult = []
    result = []

    print("<< 국내 입국한 외국인의 통계 데이터를 수집합니다. >>")
    nat_cd = input("국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : ")
    nStartYear = int(input('데이터를 몇 년부터 수집할까요? : '))
    nEndYear = int(input('데이터를 몇 년까지 수집할까요? : '))
    ed_cd = "E" # E: 방한외래관광객, D: 해외출국

    jsonResult, result, natName, ed, dataEND = getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear)

    # 파일저장 1 : json 파일
    with open('./%s_%s_%d_%s.json' %(natName, ed, nStartYear, dataEND), 'w', encoding='utf8') as outfile:
        jsonFile = json.dumps(jsonResult, indent = 4, sort_keys=True, ensure_ascii=False)
        outfile.write(jsonFile)

    # 파일저장 2 : cvs 파일
    columns = ['입국자국가', '국가코드', '입국연월', '입국자 수']
    result_df = pd.DataFrame(result, columns=columns)
    # result_df.to_csv('./%s_%s_%d_%s.csv' % (natName, ed, nStartYear, dataEND), index = False, encoding= 'cp949')
    result_df.to_csv('./%s_%s_%d_%s.csv' % (natName, ed, nStartYear, dataEND), index = False, encoding= 'utf8')

if __name__  == '__main__':
    main()
# Out:
# << 국내 입국한 외국인의 통계 데이터를 수집합니다. >>
# 국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : 112
# 데이터를 몇 년부터 수집할까요? : 2018
# 데이터를 몇 년까지 수집할까요? : 2022
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201801&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:10.763562] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 305127,
#                     "rnum": 1,
#                     "ym": 201801
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201801 : 305127]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201802&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:11.784561] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 345341,
#                     "rnum": 1,
#                     "ym": 201802
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201802 : 345341]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201803&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:12.821940] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 403413,
#                     "rnum": 1,
#                     "ym": 201803
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201803 : 403413]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201804&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:13.880466] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 366604,
#                     "rnum": 1,
#                     "ym": 201804
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201804 : 366604]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201805&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:14.925888] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 370222,
#                     "rnum": 1,
#                     "ym": 201805
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201805 : 370222]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201806&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:15.955717] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 379891,
#                     "rnum": 1,
#                     "ym": 201806
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201806 : 379891]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201807&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:17.005686] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 410337,
#                     "rnum": 1,
#                     "ym": 201807
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201807 : 410337]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201808&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:18.067404] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 478140,
#                     "rnum": 1,
#                     "ym": 201808
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201808 : 478140]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201809&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:19.087711] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 434595,
#                     "rnum": 1,
#                     "ym": 201809
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201809 : 434595]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201810&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:20.128734] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 475307,
#                     "rnum": 1,
#                     "ym": 201810
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201810 : 475307]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201811&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:21.159790] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 404256,
#                     "rnum": 1,
#                     "ym": 201811
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201811 : 404256]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201812&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:22.218892] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 416279,
#                     "rnum": 1,
#                     "ym": 201812
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201812 : 416279]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201901&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:23.310273] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 392814,
#                     "rnum": 1,
#                     "ym": 201901
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201901 : 392814]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201902&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:24.263440] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 453379,
#                     "rnum": 1,
#                     "ym": 201902
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201902 : 453379]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201903&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:25.300671] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 487623,
#                     "rnum": 1,
#                     "ym": 201903
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201903 : 487623]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201904&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:26.358151] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 493250,
#                     "rnum": 1,
#                     "ym": 201904
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201904 : 493250]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201905&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:27.396957] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 500413,
#                     "rnum": 1,
#                     "ym": 201905
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201905 : 500413]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201906&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:28.439085] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 475007,
#                     "rnum": 1,
#                     "ym": 201906
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201906 : 475007]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201907&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:29.483454] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 519132,
#                     "rnum": 1,
#                     "ym": 201907
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201907 : 519132]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201908&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:30.473107] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 578112,
#                     "rnum": 1,
#                     "ym": 201908
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201908 : 578112]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201909&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:31.501697] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 541350,
#                     "rnum": 1,
#                     "ym": 201909
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201909 : 541350]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201910&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:32.545403] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 567695,
#                     "rnum": 1,
#                     "ym": 201910
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201910 : 567695]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201911&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:33.584943] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 505369,
#                     "rnum": 1,
#                     "ym": 201911
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201911 : 505369]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=201912&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:34.638647] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 508877,
#                     "rnum": 1,
#                     "ym": 201912
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201912 : 508877]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202001&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:35.673597] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 481681,
#                     "rnum": 1,
#                     "ym": 202001
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202001 : 481681]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202002&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:36.703767] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 104086,
#                     "rnum": 1,
#                     "ym": 202002
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202002 : 104086]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202003&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:37.756845] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 16595,
#                     "rnum": 1,
#                     "ym": 202003
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202003 : 16595]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202004&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:38.823988] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 3935,
#                     "rnum": 1,
#                     "ym": 202004
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202004 : 3935]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202005&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:39.866445] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 5124,
#                     "rnum": 1,
#                     "ym": 202005
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202005 : 5124]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202006&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:40.905686] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 5051,
#                     "rnum": 1,
#                     "ym": 202006
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202006 : 5051]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202007&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:41.944894] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 9738,
#                     "rnum": 1,
#                     "ym": 202007
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202007 : 9738]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202008&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:43.001827] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 16275,
#                     "rnum": 1,
#                     "ym": 202008
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202008 : 16275]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202009&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:44.033418] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 15307,
#                     "rnum": 1,
#                     "ym": 202009
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202009 : 15307]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202010&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:45.086164] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 11477,
#                     "rnum": 1,
#                     "ym": 202010
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202010 : 11477]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202011&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:46.112846] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 9174,
#                     "rnum": 1,
#                     "ym": 202011
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202011 : 9174]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202012&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:47.178994] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 7987,
#                     "rnum": 1,
#                     "ym": 202012
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202012 : 7987]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202101&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:48.212475] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 7346,
#                     "rnum": 1,
#                     "ym": 202101
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202101 : 7346]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202102&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:49.254686] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 11982,
#                     "rnum": 1,
#                     "ym": 202102
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202102 : 11982]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202103&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:50.291806] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 18980,
#                     "rnum": 1,
#                     "ym": 202103
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202103 : 18980]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202104&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:51.352934] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 16830,
#                     "rnum": 1,
#                     "ym": 202104
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202104 : 16830]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202105&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:52.395626] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 14221,
#                     "rnum": 1,
#                     "ym": 202105
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202105 : 14221]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202106&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:53.436925] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 12942,
#                     "rnum": 1,
#                     "ym": 202106
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202106 : 12942]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202107&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:54.485425] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 13469,
#                     "rnum": 1,
#                     "ym": 202107
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202107 : 13469]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202108&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:55.531075] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 17103,
#                     "rnum": 1,
#                     "ym": 202108
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202108 : 17103]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202109&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:56.572661] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 19144,
#                     "rnum": 1,
#                     "ym": 202109
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202109 : 19144]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202110&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:57.601513] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 14035,
#                     "rnum": 1,
#                     "ym": 202110
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202110 : 14035]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202111&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:58.642851] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 12472,
#                     "rnum": 1,
#                     "ym": 202111
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202111 : 12472]
# ---------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202112&NAT_CD=112&ED_CD=E
# [2025-03-06 07:20:59.703971] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 11691,
#                     "rnum": 1,
#                     "ym": 202112
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202112 : 11691]
# ---------------------------------------------------

# %%
nEndYear = 19700105
dataEND = "{0}{1:0>2}".format(str(nEndYear), str(12))
print(dataEND)
# Out:
# 1970010512
